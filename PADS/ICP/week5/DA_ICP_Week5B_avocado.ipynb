# %% [markdown]
# #### Basic Tasks

# %% [markdown]
# #### 1 Read the data from the CSV file into a DataFrame.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/avocado.csv")

# %% [markdown]
# #### 2 Display type, memory consumption, and null count information using the info() method.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# #### 3 Display the number of unique values in each column using the nunique() method

# %%
df.nunique()
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %% [markdown]
# #### 4 Display all the rows of data that Jupyter Notebook displays by default

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1               1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2               2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3               3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4               4  11/29/2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7    2/4/2018          1.63      17074.83  2046.96    1529.20
# 18245           8   1/28/2018          1.71      13888.04  1191.70    3431.50
# 18246           9   1/21/2018          1.87      13766.76  1191.92    2452.79
# 18247          10   1/14/2018          1.93      16205.22  1527.63    2981.04
# 18248          11    1/7/2018          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
print(df)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1               1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2               2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3               3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4               4  11/29/2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7    2/4/2018          1.63      17074.83  2046.96    1529.20
# 18245           8   1/28/2018          1.71      13888.04  1191.70    3431.50
# 18246           9   1/21/2018          1.87      13766.76  1191.92    2452.79
# 18247          10   1/14/2018          1.93      16205.22  1527.63    2981.04
# 18248          11    1/7/2018          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# #### 5 Display the first and last five rows of data and the first and last four columns of data.

# %%
print("first 5 rows:")
display(df.head())

print("\nLast 5 rows:")
display(df.tail())

print("First 4 columns:")
display(df.iloc[:, :4])

print("\nLast 4 columns:")
display(df.iloc[:, df.shape[1]-4:])
# Out:
# first 5 rows:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1           1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2           2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3           3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4           4  11/29/2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# ...

# %% [markdown]
# #### 6 Choose any three columns, access them with bracket notation XX.[[XXX]], and display the first five rows of this data

# %%
cols = df.columns[:3]
display(df[cols].head())
display(df[['Unnamed: 0', 'Date', 'AveragePrice']].head())
# Out:
#    Unnamed: 0        Date  AveragePrice
# 0           0  12/27/2015          1.33
# 1           1  12/20/2015          1.35
# 2           2  12/13/2015          0.93
# 3           3   12/6/2015          1.08
# 4           4  11/29/2015          1.28
#    Unnamed: 0        Date  AveragePrice
# 0           0  12/27/2015          1.33
# 1           1  12/20/2015          1.35
# 2           2  12/13/2015          0.93
# 3           3   12/6/2015          1.08
# 4           4  11/29/2015          1.28

# %% [markdown]
# #### 7 Select one column and access it with dot notation. XX.XXX

# %%
df.Date
# Out:
# 0        12/27/2015
# 1        12/20/2015
# 2        12/13/2015
# 3         12/6/2015
# 4        11/29/2015
#             ...
# 18244      2/4/2018
# 18245     1/28/2018
# 18246     1/21/2018
# 18247     1/14/2018
# 18248      1/7/2018
# Name: Date, Length: 18249, dtype: object

# %% [markdown]
# #### 8 Multiply the Total Volume and AveragePrice columns, and store the result in a new column called EstimatedRevenue. Then, display the first five rows of this data to confirm that the column was added and has the correct values.

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1           1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2           2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3           3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4           4  11/29/2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df["EstimatedRevenue"] = df["Total Volume"] * df["AveragePrice"]

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1           1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2           2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3           3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4           4  11/29/2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region  EstimatedRevenue
# 0  2015  Albany        85434.7046
# ...

# %% [markdown]
# #### 9 Create a DataFrame that’s grouped by region and type and that includes the average price for the grouped columns. Then, reset the index and display the first five rows.

# %%
df2 = df.groupby(["region", "type"])["AveragePrice"].mean().reset_index()

df2.head()
# Out:
#                 region          type  AveragePrice
# 0               Albany  conventional      1.348757
# 1               Albany       organic      1.773314
# 2              Atlanta  conventional      1.068817
# 3              Atlanta       organic      1.607101
# 4  BaltimoreWashington  conventional      1.344201

# %% [markdown]
# #### 10 Create a bar plot that shows the mean, median, and standard deviation of the Total Volume column by year.

# %%
df3 = df.groupby("year")["Total Volume"].agg(['mean', 'median', 'std'])

# %%
df3.head()
# Out:
#               mean     median           std
# year
# 2015  7.810274e+05   76146.82  3.171256e+06
# 2016  8.584206e+05  109597.29  3.478732e+06
# 2017  8.623393e+05  122915.75  3.481957e+06
# 2018  1.066928e+06  157175.09  4.285501e+06

# %%
df3.plot(kind="bar")
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# #### Questions

# %% [markdown]
# #### Q1 How many unique regions are there?

# %%
print("Total Regions:", df["region"].nunique())
# Out:
# Total Regions: 54

# %% [markdown]
# #### Q2 What is the average price for each type of avocado (organic and conventional)? Be sure to include just the type and AveragePrice columns in the results.

# %%
df.groupby(["type"])["AveragePrice"].mean()
# Out:
# type
# conventional    1.158040
# organic         1.653999
# Name: AveragePrice, dtype: float64

# %% [markdown]
# #### Q3 Which region has the lowest average price for organic avocados? There are different ways to get the answer. You may use the grouped data that you created in task 9

# %%
df2.head()
# Out:
#                 region          type  AveragePrice
# 0               Albany  conventional      1.348757
# 1               Albany       organic      1.773314
# 2              Atlanta  conventional      1.068817
# 3              Atlanta       organic      1.607101
# 4  BaltimoreWashington  conventional      1.344201

# %%
df2[df2["type"] == "organic"].sort_values(by="AveragePrice").iloc[0, :]
# Out:
# region           Houston
# type             organic
# AveragePrice    1.270769
# Name: 37, dtype: object

# %%
df2
# Out:
#                   region          type  AveragePrice
# 0                 Albany  conventional      1.348757
# 1                 Albany       organic      1.773314
# 2                Atlanta  conventional      1.068817
# 3                Atlanta       organic      1.607101
# 4    BaltimoreWashington  conventional      1.344201
# ..                   ...           ...           ...
# 103              TotalUS       organic      1.546036
# 104                 West  conventional      0.985089
# 105                 West       organic      1.559349
# 106     WestTexNewMexico  conventional      0.842130
# 107     WestTexNewMexico       organic      1.688855
#
# [108 rows x 3 columns]

# %%
df.groupby(["type", "year"])['Total Bags'].std()
# Out:
# type          year
# conventional  2015    7.518535e+05
#               2016    1.405738e+06
#               2017    1.549660e+06
#               2018    2.033493e+06
# organic       2015    2.589149e+04
#               2016    6.756273e+04
#               2017    1.058683e+05
#               2018    1.407772e+05
# Name: Total Bags, dtype: float64

# %%
df.groupby(["year", "type"])['Total Bags'].std().plot(kind="bar")
# Out:
# <Axes: xlabel='year,type'>

# %% [markdown]
# It can be clearly seen that the standard deviation has increased for both the types of avocados, each passing year. Therefore it can be said that that the sales have become less consistent over time. It can also be noticed that, conventional avocados have much higher standard deviation then organic avocados
