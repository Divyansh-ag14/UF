# %% [markdown]
# <font color='blue'> First of all, please “Copy to Drive” to get your own copy for editing. </font>
#
# <font color='red'> Task A: Run all the cells. Task B: For places with "Complete the codes below", please replace the "XXX" placeholder with your own codes.</font>

# %% [markdown]
# ## 0 Running cells
#
# You can run the code in a cell by pressing (CMD/CTRL + ENTER) or by **clicking the run button in the top left corner**.
#
# Cells are divided into two categories:
# 1. Markdown/Text - This is a Markdown cell, which is used to provide instructions, similar to a running readme of your code.
# 2. Code cell - The Code cell contains all the code.
#
# **Tips:**
#
# * Jupyter Notebook cells are executed in order - from top to bottom. Any other order is not guaranteed to produce expected results.
#
# * You can run all the cells in this notebook, even if you are not editing them.

# %% [markdown]
# ## 1. Run a Python program

# %% [markdown]
# **How to code statements:**
#
# A *statement* performs a task.Each statement must be indented properly.

# %% [markdown]
# ### 1) Print a phrase to the screen

# %%
print("This is my first Python phrase!!!")
# Out:
# This is my first Python phrase!!!

# %% [markdown]
# ### 2) Get a number from user and assign it to a variable

# %%
num = input("Enter a number:")
print("You entered number:", num)

# %%
num2 = int(input("Enter a number:"))
num3 = num2+1
print(num2+1)
print(num3)

# %% [markdown]
# ### 3) Calculate the value of a mathematical expression

# %%
celsius = 10
fahrenheit = 9/5 *celsius +32

# %%
fahrenheit

# %% [markdown]
# ### 4) Print your name 3 times using a for loop

# %% [markdown]
# **`Indentation`**:
# * Python relies on proper indentation. Incorrect indentation causes an error.
# * With Python, the indentation is typically four spaces.

# %%
## Print your name 3 times, using a list

for i in [1, 2, 3]:
    print(i, "Ali Gator")

# %%
## Print your name 3 times, using range() function

for i in range(3):
    print(i, "Ali Gator")

# %% [markdown]
# <font color='red'>Complete the codes in the cell below. Please replace the "XXX" placeholder with your own codes. </font>

# %%
## Print "Python" 5 times, using for loop
for XXX:
  XXX

# %% [markdown]
# ## 2. Use and Define a Function

# %% [markdown]
# * A *function* is a group of statements that perform a specific task.
# * Python provides many *built-in functions* that do common tasks like gettting input data from the user and printing out data to the console.

# %%
# built-in function: print()
print("Hello out there!")
#print( )
print("Goodbye!")

# %% [markdown]
# ![](http://drive.google.com/uc?export=view&id=1nu47GpsKisZAxP6-GhCoKH3O9rzLlDku)

# %%
# How to define a simple Function
def print_welcome():
  print("Welcome to the Python Programming Course")
  print()

# %%
# How to call it-- call the function name
print_welcome()
# print_welcome    # is this line of code working? No

# %% [markdown]
# Another simple example: define a square() function

# %%
# A function that accepts one argument and returns square value of x
def square(x):
    return x**2

# %%
# call the defined square function
x = square(3)
y = square(4)
print(x+y)

# %% [markdown]
# <font color='red'>Complete the codes in the cell below. Please replace the "XXX" placeholder with your own codes. </font>

# %%
# define a function that accepts two arguments/numbers: a, b
# and returns two values (multilication, exponentiation): a*b, a**b
# a function name could be mul_exp (or something similar)

# %%
def XXX:
  XXX
  return XXX

# %% [markdown]
# A simple program illustrating chaotic behavior:

# %%
# A simple program illustrating chaotic behavior

def main():
    print("This program illustrates a chaotic function")
    x = eval(input("Enter a number between 0 and 1: "))
    for i in range(10):
        x = 3.9*x*(1-x)
        print(x)

# %%
main()   # call the defined main() function

# %% [markdown]
# ## 3. Key parts of your Python code

# %% [markdown]
# > *1) Variable*
#
# > *2) Input*
#
# > *3) Output*
#
# > *4) Simple math (to process)*

# %% [markdown]
# ### 1) Variable
#     Giving (or assigning) a name to a value so that we can refer to it at other point in the Python program
#     Simple assignment: <variable>=<expr>
#     Simultaneous assignment: <var1>, <var2>, ... <varN> = <expr1>,<expr2>, ...<exprN>

# %%
# Simple assignment
X = 7

# %%
# Simultaneous assignment
X, Y = 3, 2

# %%
Sum, diff = X+Y, X-Y
print("Sum is:", Sum)
print("diff is:", diff)

# %% [markdown]
# ### 2) Input
#     <variable> = input(<prompt>)

# %%
hometown = input("Enter your hometown:")
favorite_num = eval(input("Enter your favorite number:"))

# %% [markdown]
# ### 3) Output
#     print(<expr>, <expr>,..., <expr>, end="\n")

# %%
print("My favorite number is", X)

# %% [markdown]
# ### 4) Simple math (to process)

# %%
# Simple math example
num_bread = 2    # two bread
num_butter = 3   # three butters
num_icecream = 2 # two ice creams
# num_banana = 5
total_cost = num_bread*2.99 + num_butter*6.99 + num_icecream*8.99
print("total cost is: $", total_cost)

# %% [markdown]
# **How to code comments**
# * Block comments
# * Inline comments
# * Commented out statements
#
# ![](http://drive.google.com/uc?export=view&id=10Z6pY7Pd0W-4no7ysnGEQ_n9V7agv6wo)

# %% [markdown]
# * If you want multiline comments, you can use multiple instances of the hash tag comment, OR
# * <font color='blue'> Python uses three double quote (""") or three single quote(''') marks for comments that appear on more than one line.

# %%
# This is a Python program
# It does a calculation...

'''
This is a Python program
It does a calculation about x
and displays the results of that calculation

x = float(input("Enter a number between 0 and 1: "))
x = 3.9*x*(1-x)
x
'''

# %% [markdown]
# ![python_code.png](http://drive.google.com/uc?export=view&id=1RbmyQRqTTR5VR11uZVxGaXIueU3BEdER)

# %% [markdown]
# Example: Future Value Calculator

# %%
# File: future_value.py
# by: Murach's Python Programming

def main():
    # display a welcome message
    print("Welcome to the Future Value Calculator")
    print()

    choice = 'y'
    while choice.lower() == 'y':
      # get input from the user
      monthly_investment = float(input("Enter monthly investment:\t"))
      yearly_interest_rate = float(input("Enter yearly interest rate:\t"))
      years = int(input("Enter number of years:\t\t"))

      # convert yearly values to monthly values
      monthly_interest_rate = yearly_interest_rate / 12/ 100
      months = years *12

      # calculate the future value
      future_value = 0
      for i in range(months):
        future_value = future_value + monthly_investment
        monthly_interest_amount = future_value * monthly_interest_rate
        future_value = future_value + monthly_interest_amount

      # format and display the result
      print("Future value :\t\t", "$", round(future_value,2))
      print()

      # see if the user wants to continue
      choice = input("Continue? (y/n): ")
      print()

    print('Bye!')

# call the main function
main()

# %% [markdown]
# Let's end this first notebook with the famous `The Zen of Python` by Tim Peters:

# %%
import this
